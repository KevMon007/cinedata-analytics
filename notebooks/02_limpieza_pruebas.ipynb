# %% [markdown]
# # 02 — Limpieza y pruebas
#
# Pruebas de limpieza y transformación de datos.

# %%
import pandas as pd
import numpy as np

from src.etl.transform import clean_dataframe, fill_missing_values

# %%
# Cargar datos crudos
df = pd.read_csv('../data/raw/peliculas.csv')

# %%
# Limpiar datos
df_clean = clean_dataframe(df)
df_clean.head()

# %%
# Guardar datos limpios
df_clean.to_csv('../data/processed/peliculas_clean.csv', index=False)
