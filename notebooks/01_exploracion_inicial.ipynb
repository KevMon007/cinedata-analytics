# %% [markdown]
# # 01 — Exploración inicial
#
# Carga inicial y análisis exploratorio del dataset de películas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Cargar datos crudos
df = pd.read_csv('../data/raw/peliculas.csv')
df.head()

# %%
# Información general
df.info()
