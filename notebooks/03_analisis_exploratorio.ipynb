# %% [markdown]
# # 03 — Análisis exploratorio
#
# EDA formal del dataset final generado por el pipeline ETL.

# %%
import pandas as pd

from src.analysis.eda import (
    add_derived_columns,
    correlation_matrix,
    dataset_overview,
    decade_summary,
    genre_summary,
    most_voted_movies,
    numeric_summary,
    plot_correlation_matrix,
    top_rated_movies,
)

# %matplotlib inline

# %%
# Cargar dataset final generado por el ETL
df = pd.read_csv('../data/final/movies_dataset.csv')
df.head()

# %%
dataset_overview(df)

# %%
numeric_summary(df)

# %%
genre_summary(df, min_movies=100).head(10)

# %%
decade_summary(df)

# %%
top_rated_movies(df, top_n=10, min_votes=1000)

# %%
most_voted_movies(df, top_n=10)

# %%
correlation_matrix(df)

# %%
plot_correlation_matrix(add_derived_columns(df))
