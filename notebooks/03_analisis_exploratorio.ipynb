# %% [markdown]
# # 03 — Análisis exploratorio
#
# EDA formal del dataset limpio.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.analysis.eda import summary_stats, plot_correlation_matrix

# %matplotlib inline

# %%
# Cargar datos procesados
df = pd.read_csv('../data/processed/peliculas_clean.csv')

# %%
summary_stats(df)

# %%
plot_correlation_matrix(df)
